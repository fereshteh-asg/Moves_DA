# %%
import trj_builder
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from pylab import plot,show,hist
import json
import datetime, time
from scipy.stats.kde import gaussian_kde
from scipy.stats import norm
from numpy import linspace,hstack
import numpy
import scipy
fmt="%Y%m%dT%H%M%S"
# %matplotlib inline

# %%
json_file = "raw_data.json"
with open(json_file, "r")  as jsonf:
    data_dict = json.load(jsonf)
###============================================

t_list=[]
for user,v in data_dict.iteritems():
    user_trj=0
    #print v["info"]["name"]
    for day in v["data"]:
        if (day!={}):
            dist_list,total_trj,diff=trj_builder.trajectory_builder(v["data"][day])
            for i in range(0,len(total_trj)):
                s_t=total_trj[i][0]['time'] 
                e_t=total_trj[i][-1]['time'] 
                s_t= datetime.datetime.strptime(s_t.split('+')[0],fmt)
                e_t= datetime.datetime.strptime(e_t.split('+')[0],fmt)  
                diff= e_t-s_t
                t_list.append(diff.seconds/60)
                user_trj+=1
print len(t_list)
plt.hist(t_list, bins=300, normed=True)
plt.xlim(0,400)
plt.xlabel('Trajectory Duration (Minutes)')
plt.show()
# Out:
# 0635266892 20140929 20140929T085104+0200 Christian Muvingi 20140929T212628+0200
# 0635266892 20140914 20140914T121025+0200 Christian Muvingi 20140914T231852+0200
# 0635266892 20140913 20140913T063633+0200 Christian Muvingi 20140913T154152+0200
# 0635266892 20140911 20140911T132050+0200 Christian Muvingi 20140911T184055+0200
# 0635266892 20141002 20141002T000000+0200 Christian Muvingi 20141002T235959+0200
# 0635266892 20141003 20141003T000000+0200 Christian Muvingi 20141003T133458+0200
# 0635266892 20141001 20141001T173427+0200 Christian Muvingi 20141001T235959+0200
# 0620140129 20140910 20140910T131632+0200 Pooria Rad 20140910T225035+0200
# 0663996261
#  20140916 20140916T095109+0200 Mohammad Javad Shole Sadi 20140916T172052+0200
# 1094

# %%
fig = plt.figure(figsize=(8,6))
plt.hist(t_list,normed=True,bins=500,alpha=.4, color='g',label= '')
plt.xlim(0,160)
pdf = gaussian_kde(t_list)
cdf = stats.binom.cdf
x = linspace(0,160,300)
plot(x,pdf(x), 'b')
plt.xlabel("Trajectory Duration (Minutes)")
plt.title("Time distribution of trajectories")
plt.ylabel("Probability")
plt.legend()
plt.savefig("time_dist")
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
print 'Avrage trajectory time:', numpy.mean(t_list)
plt.xlabel("Time (Minutes)")
plt.title("Cumulative distribution function")
plt.ylabel("Probability")
plt.legend()
plt.savefig("time_cdf", format='pdf')
plt.plot(x,cdf(x, 200, 0.2))
plt.show()
# Out:
# Avrage trajectory time: 36.5374771481
